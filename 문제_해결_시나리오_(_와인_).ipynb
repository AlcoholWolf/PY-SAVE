# %% [markdown]
# <a href="https://colab.research.google.com/github/AlcoholWolf/PY-SAVE/blob/main/%EB%AC%B8%EC%A0%9C_%ED%95%B4%EA%B2%B0_%EC%8B%9C%EB%82%98%EB%A6%AC%EC%98%A4_(_%EC%99%80%EC%9D%B8_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

import pandas_profiling as pp

import warnings
warnings.filterwarnings(action='ignore')

plt.style.use('dark_background')

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

train= train.drop(['index'],axis=1)

# train.info()
# train.describe(include='all')

# %%
# pp.ProfileReport(train)  작동 안함 ㅇㅅㅇ

# %%
cl = train.select_dtypes(exclude='object').columns.tolist()
cl.remove('quality')
def dp(df, col):
    for col in col:
        f, ax = plt.subplots(figsize=(16,4))
        sns.stripplot(x=df['quality'],y=df[col],hue=df['quality'],size=2)
        
show_dist_plot(train, cl)

# %%
# 대체적으로 퀄리티가 높은 와인(9등급)은 산성이 3.2쯤이고, 당도와 떫음의 정도가 낮고 산도가 조금 있으며, 스파클을 제거하지 않은 내츄럴 와인인것을 알 수 있다.

# 퀄리티가 8등급인 와인은 당도, 산도, 떫음 등이 무난한 정도(평균)에 머물고, 첨가형 와인이 주를 이룬다는것을 알 수 있다.

# 퀄리티가 7등급인 와인은 당도와 산도 떫음이 전체적으로 포진해 있고, 첨가물이 없는 와인이 주를 이룬다는걸 알 수 있다.

# 퀄리티가 6등급인 와인은 모든 특징이 7,8,9등급의 평균급이다. (딱히 특별하지 않다.)

# 5등급 아래로는 이렇다 할 특징이 없다. 전체적으로 퍼져있을 뿐이다.
